# %%
import asyncio

import cv2
import numpy as np
import pandas as pd
from IPython.display import clear_output
from scipy.spatial.transform import Rotation
from sksurgerynditracker.nditracker import NDITracker

ROMFILE_DIR = "./tracking/Slicer/rom_config/"

rom_list = ["8700339", "custom_002"]

TRACKER_SETTINGS = {
    "tracker type": "polaris",
    "romfiles": list(map(lambda x: ROMFILE_DIR + x + ".rom", rom_list)),
}


class SyncCamTrak:
    def __init__(self):
        print("\nInitializing tracker...")
        self.tracker = NDITracker(TRACKER_SETTINGS)
        self.tracker.start_tracking()

        print("Initializing camera...\n")
        self.cap = cv2.VideoCapture(0)
        fps = int(self.cap.get(cv2.CAP_PROP_FPS))
        w = int(self.cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        h = int(self.cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        fourcc = cv2.VideoWriter_fourcc("m", "p", "4", "v")
        self.video = cv2.VideoWriter("eval.mp4", fourcc, fps, (w, h))

    def get_transform(self, tool, frame_num, mat):
        assert mat.shape == (4, 4)
        x = mat[0, 3]
        y = mat[1, 3]
        z = mat[2, 3]
        rot_mat = mat[:3, :3]
        rot = Rotation.from_matrix(rot_mat).as_euler("ZXY")
        alpha, beta, gamma = np.rad2deg(rot)
        r1, r2, r3, r4, r5, r6, r7, r8, r9 = rot_mat.flatten()
        print(
            """
        =================
        ID: {}
        Frame: #{}
        -----------------
        Tx: {:05.2f} mm
        Ty: {:05.2f} mm
        Tz: {:05.2f} mm
        Rx: {:05.2f} deg
        Ry: {:05.2f} deg
        Rz: {:05.2f} deg
        =================
        """.format(
                tool,
                frame_num,
                x,
                y,
                z,
                alpha,
                beta,
                gamma,
            )
        )
        return frame_num, x, y, z, r1, r2, r3, r4, r5, r6, r7, r8, r9

    def on(self):
        j = 0
        tool_dict = {"1": "forceps", "2": "endoscope"}
        transform_dict = {"forceps": [], "endoscope": []}
        while True:
            clear_output(wait=True)
            id_, _, _, mat, _ = self.tracker.get_frame()
            for i in id_:
                tool = tool_dict[str(i)]
                transform = self.get_transform(tool, j, mat[i - 1])
                transform_dict[tool].append(transform)

            ret, frame = self.cap.read()
            cv2.imshow("camera", frame)
            cv2.imwrite("images/img_{:05d}.jpg".format(j+1), frame)
            self.video.write(frame)
            j += 1
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        for tool in ["forceps", "endoscope"]:
            df = pd.DataFrame(
                transform_dict[tool],
                columns=[
                    "frame",
                    "x",
                    "y",
                    "z",
                    "r1",
                    "r2",
                    "r3",
                    "r4",
                    "r5",
                    "r6",
                    "r7",
                    "r8",
                    "r9",
                ],
            )
            df.to_csv("{}.csv".format(tool), index=False)
        print("\nSaved successfully!!")
        self.cap.release()
        cv2.destroyAllWindows()


main = SyncCamTrak()

input("Press ENTER to start recording\n")

print('Press q to stop recording')

if __name__ == "__main__":
    main.on()
# Out:
# Initializing tracker...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-bb02ec12d8a8> in <module>
#     112
#     113
# --> 114 main = SyncCamTrak()
#     115
#     116 input("Press ENTER to start recording\n")
#
# <ipython-input-5-bb02ec12d8a8> in __init__(self)
#      21     def __init__(self):
#      22         print("\nInitializing tracker...")
# ---> 23         self.tracker = NDITracker(TRACKER_SETTINGS)
#      24         self.tracker.start_tracking()
#      25
#
# ~\Anaconda3\envs\dl\lib\site-packages\sksurgerynditracker\nditracker.py in __init__(self, configuration)
#      67
#      68         if self._tracker_type == "polaris":
# ---> 69             self._connect_polaris(configuration)
#      70
#      71         if self._tracker_type == "dummy":
#
# ~\Anaconda3\envs\dl\lib\site-packages\sksurgerynditracker\nditracker.py in _connect_polaris(self, configuration)
#     116
#     117     def _connect_polaris(self, configuration):
# --> 118         self._connect_serial(configuration)
#     119         self._read_sroms_from_file()
#     120
#
# ~\Anaconda3\envs\dl\lib\site-packages\sksurgerynditracker\nditracker.py in _connect_serial(self, configuration)
#     164                 '\t3) Do you have sufficient privilege to connect to '
#     165                 'the device? (e.g. on Linux are you part of the "dialout" '
# --> 166                 'group?)'.format(ports_to_probe))
#     167
#     168         self._device = ndicapy.ndiOpen(name)
#
# OSError: Could not find any NDI device in 20 serial port candidates checked. Please check the following:
# 	1) Is an NDI device connected to your computer?
# 	2) Is the NDI device switched on?
# 	3) Do you have sufficient privilege to connect to the device? (e.g. on Linux are you part of the "dialout" group?)
